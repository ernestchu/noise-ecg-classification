# %%
import torch
import torch.nn as nn
import numpy as np
import h5py
import os

encoding = ['N', 'R', 'A', 'x', 'V', '~', '+']

class NSTDB(torch.utils.data.Dataset):
    def __init__(self):
        self.h5_list = []
        for root, dirs, files in os.walk('../data'):
            for f in files:
                path = os.path.join(root, f)
                with h5py.File(path, 'r') as h5:
                    if h5['MLII'][:].size == 0:
                        continue
                    if h5['V1'][:].size == 0:
                        continue
                self.h5_list.append(os.path.join(root, f))
        
    def __getitem__(self, index):
        with h5py.File(self.h5_list[index], 'r') as f:
            id_ = f['id'][()]
            MLII = torch.tensor(f['MLII'][:])
            V1 = torch.tensor(f['V1'][:])
            label = torch.tensor(encoding.index(f['label'][()]))
            SNR = f['SNR'][()]
            return {
                'id': id_,
                'MLII': MLII.float(),
                'V1': V1.float(),
                'label': label,
                'SNR': SNR
            }
    def __len__(self):
        return len(self.h5_list)
dataset = NSTDB()

# %%
import matplotlib.pyplot as plt
id_, MLII, V1, label, SNR = dataset[10000].values()
plt.plot(range(len(MLII)), MLII)
plt.show()
print('Label:', label)
print('SNR:', SNR)
# Out:
# Label: tensor(3)
# SNR: 24

# %%
dataset_train, dataset_val = torch.utils.data.random_split(dataset, [int(0.7*len(dataset)), len(dataset)-int(0.7*len(dataset))])
print(len(dataset_train), len(dataset_val))
from torch.utils.data import DataLoader
BATCH_SIZE = 256
train_loader = DataLoader(dataset_train, batch_size=BATCH_SIZE, shuffle=True)
val_loader = DataLoader(dataset_val, batch_size=BATCH_SIZE, shuffle=True)
# Out:
# 18446 7906

# %%
class ConvModel(nn.Module):
    def __init__(self):
        super(ConvModel, self).__init__()
#         self.conv = nn.Sequential(
#             nn.Conv1d(1, 32, 3),
#             nn.ReLU(),
#             nn.BatchNorm1d(32),
#             nn.Conv1d(32, 64, 3),
#             nn.ReLU(),
#             nn.BatchNorm1d(64),
#             nn.Conv1d(64, 128, 3),
#         )
        self.fc = nn.Sequential(
            nn.Linear(504, 1000),
            nn.ReLU(),
            nn.Linear(1000, 1000),
            nn.ReLU(),
            nn.Linear(1000, 500),
            nn.ReLU(),
            nn.Linear(500, 7)
        )
    def forward(self, x):
        x = self.fc(x)
        return x
model = ConvModel().cuda()

# %%
criterion = nn.CrossEntropyLoss().cuda()
optimizer = torch.optim.SGD(model.parameters(), lr=1e-3, momentum=0.9)

# %%
def train(input_data, model, criterion, optimizer):
    model.train()
    loss_list = []
    total_count = 0
    acc_count = 0
    for data in input_data:
        id_, MLII, V1, label, SNR = data['id'], data['MLII'].cuda(), data['V1'].cuda(), data['label'].cuda(), data['SNR']
        
        optimizer.zero_grad()
        out = model(torch.cat((MLII, V1), 1))
        loss = criterion(out, label)
        loss.backward()
        optimizer.step()
        
        _, pred = torch.max(out, 1)
        total_count += label.shape[0]
        acc_count += (pred == label).sum().item()
        loss_list.append(loss.item())
        
    acc = acc_count/total_count
    loss = sum(loss_list)/len(loss_list)
    return acc, loss

# %%
def val(input_data, model, criterion):
    model.train()
    loss_list = []
    total_count = 0
    acc_count = 0
    with torch.no_grad():
        for data in input_data:
            id_, MLII, V1, label, SNR = data['id'], data['MLII'].cuda(), data['V1'].cuda(), data['label'].cuda(), data['SNR']

            optimizer.zero_grad()
            out = model(torch.cat((MLII, V1), 1))
            loss = criterion(out, label)

            _, pred = torch.max(out, 1)
            total_count += label.shape[0]
            acc_count += (pred == label).sum().item()
            loss_list.append(loss.item())
        
    acc = acc_count/total_count
    loss = sum(loss_list)/len(loss_list)
    return acc, loss

# %%
max_epochs = 50
log_interval = 1

train_acc_list = []
train_loss_list = []
val_acc_list = []
val_loss_list = []

min_loss = 1000000
best_model = None
best_log_vars = None

print("Start training...")
for epoch in range(1, max_epochs+1):
    train_acc, train_loss = train(train_loader, model, criterion, optimizer)
    val_acc, val_loss = val(val_loader, model, criterion)
    
    train_acc_list.append(train_acc)
    train_loss_list.append(train_loss)
    val_acc_list.append(val_acc)
    val_loss_list.append(val_loss)
    
#     if val_loss < min_loss:
#         min_loss = val_loss
#         best_model = model.state_dict()
#         best_log_vars = (log_var_a, log_var_b)
        
    if epoch % log_interval == 0:
        print('')
        print('=' * 20, 'Epoch', epoch, '=' * 20)
        print('Train Acc: {:.6f} Train Loss: {:.6f}'.format(train_acc, train_loss))
        print('  Val Acc: {:.6f}   Val Loss: {:.6f}'.format(val_acc, val_loss))
# Out:
# Start training...
#
# ==================== Epoch 1 ====================
# Train Acc: 0.437927 Train Loss: 1.759683
#   Val Acc: 0.495573   Val Loss: 1.439356
#
# ==================== Epoch 2 ====================
# Train Acc: 0.529383 Train Loss: 1.117888
#   Val Acc: 0.817860   Val Loss: 0.887061
#
# ==================== Epoch 3 ====================
# Train Acc: 0.830099 Train Loss: 0.755384
#   Val Acc: 0.841513   Val Loss: 0.600150
#
# ==================== Epoch 4 ====================
# Train Acc: 0.834544 Train Loss: 0.540011
#   Val Acc: 0.843916   Val Loss: 0.472898
#
# ==================== Epoch 5 ====================
# Train Acc: 0.836496 Train Loss: 0.443369
#   Val Acc: 0.846699   Val Loss: 0.394978
#
# ==================== Epoch 6 ====================
# Train Acc: 0.895696 Train Loss: 0.368646
#   Val Acc: 0.928029   Val Loss: 0.330477
#
# ==================== Epoch 7 ====================
# Train Acc: 0.927572 Train Loss: 0.314628
#   Val Acc: 0.933342   Val Loss: 0.284663
#
# ==================== Epoch 8 ====================
# Train Acc: 0.929416 Train Loss: 0.273253
#   Val Acc: 0.933721   Val Loss: 0.257070
#
# ==================== Epoch 9 ====================
# Train Acc: 0.930337 Train Loss: 0.251840
#   Val Acc: 0.933848   Val Loss: 0.239911
#
# ==================== Epoch 10 ====================
# Train Acc: 0.930934 Train Loss: 0.241715
#   Val Acc: 0.934354   Val Loss: 0.228442
#
# ==================== Epoch 11 ====================
# Train Acc: 0.931693 Train Loss: 0.226649
#   Val Acc: 0.934480   Val Loss: 0.220418
#
# ==================== Epoch 12 ====================
# Train Acc: 0.931964 Train Loss: 0.216883
#   Val Acc: 0.934354   Val Loss: 0.213427
#
# ==================== Epoch 13 ====================
# Train Acc: 0.932506 Train Loss: 0.210318
#   Val Acc: 0.935619   Val Loss: 0.207483
#
# ==================== Epoch 14 ====================
# Train Acc: 0.937710 Train Loss: 0.210715
#   Val Acc: 0.942575   Val Loss: 0.202619
#
# ==================== Epoch 15 ====================
# Train Acc: 0.945679 Train Loss: 0.202056
#   Val Acc: 0.947129   Val Loss: 0.198149
#
# ==================== Epoch 16 ====================
# Train Acc: 0.947577 Train Loss: 0.201274
#   Val Acc: 0.949279   Val Loss: 0.194261
#
# ==================== Epoch 17 ====================
# Train Acc: 0.949366 Train Loss: 0.195892
#   Val Acc: 0.950417   Val Loss: 0.191075
#
# ==================== Epoch 18 ====================
# Train Acc: 0.950070 Train Loss: 0.190390
#   Val Acc: 0.951176   Val Loss: 0.187179
#
# ==================== Epoch 19 ====================
# Train Acc: 0.950721 Train Loss: 0.193725
#   Val Acc: 0.951556   Val Loss: 0.184045
#
# ==================== Epoch 20 ====================
# Train Acc: 0.951697 Train Loss: 0.180790
#   Val Acc: 0.951429   Val Loss: 0.181149
#
# ==================== Epoch 21 ====================
# Train Acc: 0.952293 Train Loss: 0.177903
#   Val Acc: 0.951809   Val Loss: 0.178523
#
# ==================== Epoch 22 ====================
# Train Acc: 0.954950 Train Loss: 0.174568
#   Val Acc: 0.958639   Val Loss: 0.175726
#
# ==================== Epoch 23 ====================
# Train Acc: 0.958040 Train Loss: 0.174804
#   Val Acc: 0.960916   Val Loss: 0.173720
#
# ==================== Epoch 24 ====================
# Train Acc: 0.960533 Train Loss: 0.176348
#   Val Acc: 0.961422   Val Loss: 0.171059
#
# ==================== Epoch 25 ====================
# Train Acc: 0.960750 Train Loss: 0.166536
#   Val Acc: 0.961675   Val Loss: 0.168579
#
# ==================== Epoch 26 ====================
# Train Acc: 0.961347 Train Loss: 0.164218
#   Val Acc: 0.961801   Val Loss: 0.166707
#
# ==================== Epoch 27 ====================
# Train Acc: 0.961618 Train Loss: 0.161992
#   Val Acc: 0.962307   Val Loss: 0.164901
#
# ==================== Epoch 28 ====================
# Train Acc: 0.961889 Train Loss: 0.161305
#   Val Acc: 0.962434   Val Loss: 0.163220
#
# ==================== Epoch 29 ====================
# Train Acc: 0.962051 Train Loss: 0.160380
#   Val Acc: 0.962307   Val Loss: 0.161526
#
# ==================== Epoch 30 ====================
# Train Acc: 0.962160 Train Loss: 0.155921
#   Val Acc: 0.962687   Val Loss: 0.159654
#
# ==================== Epoch 31 ====================
# Train Acc: 0.962214 Train Loss: 0.155161
#   Val Acc: 0.962687   Val Loss: 0.158091
#
# ==================== Epoch 32 ====================
# Train Acc: 0.962485 Train Loss: 0.152608
#   Val Acc: 0.962813   Val Loss: 0.156731
#
# ==================== Epoch 33 ====================
# Train Acc: 0.962594 Train Loss: 0.151159
#   Val Acc: 0.962687   Val Loss: 0.155173
#
# ==================== Epoch 34 ====================
# Train Acc: 0.962702 Train Loss: 0.152046
#   Val Acc: 0.962813   Val Loss: 0.153699
#
# ==================== Epoch 35 ====================
# Train Acc: 0.962810 Train Loss: 0.150243
#   Val Acc: 0.962813   Val Loss: 0.152662
#
# ==================== Epoch 36 ====================
# Train Acc: 0.962919 Train Loss: 0.146358
#   Val Acc: 0.963066   Val Loss: 0.151328
#
# ==================== Epoch 37 ====================
# Train Acc: 0.963136 Train Loss: 0.144918
#   Val Acc: 0.963066   Val Loss: 0.150341
#
# ==================== Epoch 38 ====================
# Train Acc: 0.963190 Train Loss: 0.145990
#   Val Acc: 0.963066   Val Loss: 0.149446
#
# ==================== Epoch 39 ====================
# Train Acc: 0.963461 Train Loss: 0.142313
#   Val Acc: 0.963572   Val Loss: 0.147708
#
# ==================== Epoch 40 ====================
# Train Acc: 0.963678 Train Loss: 0.144122
#   Val Acc: 0.963572   Val Loss: 0.147058
#
# ==================== Epoch 41 ====================
# Train Acc: 0.963895 Train Loss: 0.140964
#   Val Acc: 0.963445   Val Loss: 0.145816
#
# ==================== Epoch 42 ====================
# Train Acc: 0.964057 Train Loss: 0.139565
#   Val Acc: 0.963445   Val Loss: 0.144629
#
# ==================== Epoch 43 ====================
# Train Acc: 0.964166 Train Loss: 0.137730
#   Val Acc: 0.963319   Val Loss: 0.143761
#
# ==================== Epoch 44 ====================
# Train Acc: 0.964274 Train Loss: 0.136592
#   Val Acc: 0.963572   Val Loss: 0.142750
#
# ==================== Epoch 45 ====================
# Train Acc: 0.964599 Train Loss: 0.135606
#   Val Acc: 0.963572   Val Loss: 0.141906
#
# ==================== Epoch 46 ====================
# Train Acc: 0.964870 Train Loss: 0.134724
#   Val Acc: 0.963698   Val Loss: 0.141466
#
# ==================== Epoch 47 ====================
# Train Acc: 0.965250 Train Loss: 0.133666
#   Val Acc: 0.963825   Val Loss: 0.140496
#
# ==================== Epoch 48 ====================
# Train Acc: 0.965304 Train Loss: 0.135572
#   Val Acc: 0.963951   Val Loss: 0.139865
#
# ==================== Epoch 49 ====================
# Train Acc: 0.965738 Train Loss: 0.131722
#   Val Acc: 0.964204   Val Loss: 0.138953
#
# ==================== Epoch 50 ====================
# Train Acc: 0.965900 Train Loss: 0.133265
#   Val Acc: 0.963951   Val Loss: 0.137868

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 4))
plt.plot(range(len(train_loss_list)), train_loss_list)
plt.plot(range(len(val_loss_list)), val_loss_list, c='r')
plt.legend(['train_loss', 'val'])
plt.title('Loss')
plt.show()
plt.figure(figsize=(12, 4))
plt.plot(range(len(train_acc_list)), train_acc_list)
plt.plot(range(len(val_acc_list)), val_acc_list, c='r')
plt.legend(['train', 'val'])
plt.show()
